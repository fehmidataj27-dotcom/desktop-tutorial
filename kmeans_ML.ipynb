# %% [markdown]
# <a href="https://colab.research.google.com/github/fehmidataj27-dotcom/desktop-tutorial/blob/main/kmeans_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import required libraries
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load the Iris dataset
iris = load_iris()
X = iris.data  # features
y_true = iris.target  # actual labels (used only for comparison, not clustering)

# Create a DataFrame for better visualization
df = pd.DataFrame(X, columns=iris.feature_names)
df['Actual_Label'] = y_true

# Apply KMeans Clustering
k = 3  # We know Iris has 3 natural clusters
kmeans = KMeans(n_clusters=k, random_state=42)
df['Cluster_Label'] = kmeans.fit_predict(X)

# # Compare actual vs cluster labels using seaborn pairplot
# sns.pairplot(df, hue='Cluster_Label', palette='viridis', corner=True)
# plt.suptitle('K-Means Clustering on Iris Dataset', y=1.02)
# plt.show()

# Optional: visualize clustering in 2D using first two features
plt.figure(figsize=(8, 6))
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=df['Cluster_Label'], palette='viridis', s=100)
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, marker='X', label='Centroids')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
plt.title('K-Means Clustering (2 Features)')
plt.legend()
plt.grid(True)
plt.show()
